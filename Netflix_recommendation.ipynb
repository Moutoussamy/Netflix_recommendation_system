# %% [markdown]
# # NETFLIX Content Based Recommandation System (CB-RS)
#
#
# "*TV Shows and Movies listed on Netflix*
#
# *This dataset consists of tv shows and movies available on Netflix as of 2019. The dataset is collected from Flixable which is a third-party Netflix search engine.*"

# %% [markdown]
# # The Goal
#
# The goal of this project is to write a RS for movie/TV shows based on the Netflix data (From [Kaggle](https://www.kaggle.com/shivamb/netflix-shows)).

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import nltk # Natural Language Toolkit
import datetime
from string import punctuation
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.corpus import wordnet 
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer #Lemmatization
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics.pairwise import linear_kernel
from sklearn.feature_extraction.text import TfidfVectorizer #TF-IDF vectorization
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# ## Function definitions

# %%
def get_wordnet_pos(word):
    
    """
    Map POS tag to first character (for lemmatization)
    :param word: a word in your dataset
    :return: Part of speech tag
    """
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)

    
def get_recommendations(data,title,CosineSimMAt,indices,title_column):
    """
    Recommend 10 movies based on a movie title.
    :param data: your dataset
    :param title: the movie title
    :param CosineSimMAt: The cosine similiarity matrix
    :param indices: indieces correspoding to movie titles
    :param title_column: title in the dataset corresponding to the movie titles
    """
    
    print("\nYou watched '{0}', you may also like:\n".format(title))
    
    idx = indices[title]
    scores = list(enumerate(CosineSimMAt[idx]))
    scores = sorted(scores, key=lambda x: x[1], reverse=True)
    scores_top_10 = scores[1:11]
    movie_indices = [i[0] for i in scores_top_10]
    
    i = 1
    for movie in data[title_column].iloc[movie_indices]:
        print("Recommendation #{0}: {1}".format(i,movie))
        i += 1

def lemmatize_text(text):
    """
    lemmatization of each word on the text
    """
    return [lemmatizer.lemmatize(word,get_wordnet_pos(word)) for word in text]

# %% [markdown]
# # Step 1: Data collection - Read the data
#
# The Dataset was collected on [Kaggle](https://www.kaggle.com/shivamb/netflix-shows).

# %%
netfilx_raw_data = pd.read_csv("netflix_titles.csv")

# %%
netfilx_raw_data.head(100) #Let see the first rows
# Out:
#      show_id     type                                    title  \
# 0   81145628    Movie  Norm of the North: King Sized Adventure
# 1   80117401    Movie               Jandino: Whatever it Takes
# 2   70234439  TV Show                       Transformers Prime
# 3   80058654  TV Show         Transformers: Robots in Disguise
# 4   80125979    Movie                             #realityhigh
# ..       ...      ...                                      ...
# 95  81016750    Movie                              The 3rd Eye
# 96  81002866    Movie             The Sinking Of Van Der Wijck
# 97  80992039    Movie                           Two Catalonias
# 98  80126507    Movie                     Bobby Sands: 66 Days
# 99  80225885  TV Show                            Bard of Blood
#
#                              director  \
# 0            Richard Finn, Tim Maltby
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                    Fernando Lebrija
# ..                                ...
# 95                       Rocky Soraya
# 96                       Sunil Soraya
# 97  Álvaro Longoria, Gerardo Olivares
# 98                      Brendan Byrne
# 99                                NaN
#
#                                                  cast  \
# 0   Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                    Jandino Asporaat
# 2   Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3   Will Friedle, Darren Criss, Constance Zimmer, ...
# 4   Nesta Cooper, Kate Walsh, John Michael Higgins...
# ..                                                ...
# 95  Jessica Mila, Denny Sumargo, Citra Prima, Bian...
# 96  Herjunot Ali, Pevita Pearce, Reza Rahadian, Ra...
# 97                                                NaN
# 98                                                NaN
# 99  Emraan Hashmi, Viineet Kumar, Sobhita Dhulipal...
#
#                                      country          date_added  \
# 0   United States, India, South Korea, China   September 9, 2019
# 1                             United Kingdom   September 9, 2016
# 2                              United States   September 8, 2018
# 3                              United States   September 8, 2018
# 4                              United States   September 8, 2017
# ..                                       ...                 ...
# 95                                 Indonesia  September 28, 2018
# 96                                 Indonesia  September 28, 2018
# 97                                     Spain  September 28, 2018
# 98                   Ireland, United Kingdom  September 28, 2017
# 99                                     India  September 27, 2019
#
#     release_year    rating  duration  \
# 0           2019     TV-PG    90 min
# 1           2016     TV-MA    94 min
# 2           2013  TV-Y7-FV  1 Season
# 3           2016     TV-Y7  1 Season
# 4           2017     TV-14    99 min
# ..           ...       ...       ...
# 95          2018     TV-MA   108 min
# 96          2013     TV-14   163 min
# 97          2018     TV-MA   117 min
# 98          2016     TV-14   106 min
# 99          2019     TV-MA  1 Season
#
#                                             listed_in  \
# 0                  Children & Family Movies, Comedies
# 1                                     Stand-Up Comedy
# 2                                            Kids' TV
# 3                                            Kids' TV
# 4                                            Comedies
# ..                                                ...
# 95                Horror Movies, International Movies
# 96      Dramas, International Movies, Romantic Movies
# 97                Documentaries, International Movies
# 98                                      Documentaries
# 99  International TV Shows, TV Action & Adventure,...
#
#                                           description
# 0   Before planning an awesome wedding for his gra...
# 1   Jandino Asporaat riffs on the challenges of ra...
# 2   With the help of three human allies, the Autob...
# 3   When a prison ship crash unleashes hundreds of...
# 4   When nerdy high schooler Dani finally attracts...
# ..                                                ...
# 95  When her little sister claims she sees the dea...
# 96  When a young man leaves home to fulfill the wi...
# 97  Lawmakers and activists with conflicting ideol...
# 98  In 1981, an imprisoned Irish Republican Army s...
# 99  Years after a disastrous job in Balochistan, a...
#
# [100 rows x 12 columns]

# %% [markdown]
# The dataset contains 12 descriptors (columns):
# - Show_id (int)
# - type (str)
# - director (str)
# - cast (str)
# - country (str)
# - date_added (str)
# - release_year (int)
# - rating (str)
# - duration (str)
# - listed_in (str)
# - description (str)

# %% [markdown]
# # Step 2: Let's visualize and clean the data for CB-RS

# %% [markdown]
# ## Overview on the dataset

# %%
netfilx_raw_data.info() #get some info about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6234 entries, 0 to 6233
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       6234 non-null   int64
#  1   type          6234 non-null   object
#  2   title         6234 non-null   object
#  3   director      4265 non-null   object
#  4   cast          5664 non-null   object
#  5   country       5758 non-null   object
#  6   date_added    6223 non-null   object
#  7   release_year  6234 non-null   int64
#  8   rating        6224 non-null   object
#  9   duration      6234 non-null   object
#  10  listed_in     6234 non-null   object
#  11  description   6234 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 584.6+ KB

# %% [markdown]
# ## Distribution TV shows/Movies - Donut chart ( like a pie chart but more cool ;) )

# %%
fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(aspect="equal"))
wedges, texts, autotexts = ax.pie(netfilx_raw_data.type.value_counts(),
                                  explode=(0.03,0.03),labels=netfilx_raw_data.type.value_counts().index,
                                  colors=['#ff9999','#66b3ff'],autopct='%1.1f%%', shadow=True,pctdistance=0.4)

plt.setp(texts, size=18)
plt.setp(autotexts, size=18)

centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.tight_layout()
plt.show()

# %% [markdown]
# Here we can see that movies represent the larger part of this dataset (68.4%)

# %% [markdown]
# ## Release per year (2011 - 2018)

# %%
plt.figure(figsize=(16,8))
ax = sns.countplot(y='release_year', data=netfilx_raw_data,
                   order=netfilx_raw_data['release_year'].value_counts().index[0:10],
                   palette="Set3")
plt.xlabel("Nb. of movie/TV show",fontsize=14)
plt.ylabel("Year",fontsize=14)
plt.show()

# %% [markdown]
# ## Release per Country (Top 10)

# %%
plt.figure(figsize=(16,8))
ax = sns.countplot(y='country', data=netfilx_raw_data,
                   order=netfilx_raw_data['country'].value_counts().index[0:10],
                   palette="Set3")
plt.xlabel("Nb. of movie/TV show",fontsize=14)
plt.ylabel("Country",fontsize=14)
plt.show()

# %% [markdown]
# ## Nb. of realease per month

# %%
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September',\
          'October', 'November', 'December']
date_of_realease = netfilx_raw_data[['date_added']].dropna()

# Get Months and Years
date_of_realease['Year'] = date_of_realease['date_added'].apply(lambda date : date.split(',')[-1]) #Get Month
date_of_realease['Month'] = date_of_realease['date_added'].apply(lambda date : date.split()[0]) #Get Year


realese_date_df = date_of_realease.groupby('Year')['Month']
realese_date_df = realese_date_df.value_counts().unstack().fillna(0)[months]

ax = plt.subplots(figsize=(17, 8))
sns.heatmap(realese_date_df.T, cmap="YlGnBu") # beatiful sns plot 
plt.show()

# %% [markdown]
# ## Movie duration distribution

# %%
netfilx_movies = netfilx_raw_data[netfilx_raw_data['type'] == "Movie"]
netfilx_duration = netfilx_movies["duration"].str.replace(' min','').astype(int)

plt.subplots(figsize=(14, 6))
sns.set(style="darkgrid")
sns.kdeplot(data=netfilx_duration, shade=True)
plt.xlabel("Duration (Min)")
plt.show()

print("""
Average duration of a movie: {0} min
Standard diviation: {1} min
""".format(round(np.mean(netfilx_duration),3),round(np.std(netfilx_duration),3)))
# Out:
# Average duration of a movie: 99.101 min
# Standard diviation: 28.072 min

# %% [markdown]
# ## Cleaning for wordclouds and RS
# - Removing NA
# - Every letter in lowercase
# - Removing ponctuations
# - Tokenization
# - Removing stopwords
# - Lemmatization

# %%
netfilx_raw_data = pd.read_csv("netflix_titles.csv") 
list_stopwords = stopwords.words('english')

lemmatizer = WordNetLemmatizer()

netfilx_raw_data['Original_title'] = netfilx_raw_data['title']

for descriptors in ['title','listed_in','description']:
    netfilx_raw_data[descriptors] = netfilx_raw_data[descriptors].dropna() #remove NA
    netfilx_raw_data[descriptors] = netfilx_raw_data[descriptors].str.lower() #lower everything
    netfilx_raw_data[descriptors] = netfilx_raw_data[descriptors].str.replace('[^\w\s]','') #remove ponctuations
    netfilx_raw_data[descriptors] = netfilx_raw_data[descriptors].apply(word_tokenize) #tokenization
    netfilx_raw_data[descriptors] = netfilx_raw_data[descriptors]\
    .apply(lambda x: [word for word in x if word not in list_stopwords]) #remove stopwords
    netfilx_raw_data[descriptors] = netfilx_raw_data[descriptors].apply(lemmatize_text) #lemmatize
    netfilx_raw_data[descriptors] = netfilx_raw_data[descriptors].str.join(" ") #join everything

#let's see what the title column look like now:
print(netfilx_raw_data['title'])
# Out:
# 0             norm north king size adventure
# 1                      jandino whatever take
# 2                          transformer prime
# 3                 transformer robot disguise
# 4                                realityhigh
#                         ...
# 6229                              red v blue
# 6230                                   maron
# 6231    little baby bum nursery rhyme friend
# 6232             young doctor notebook story
# 6233                                  friend
# Name: title, Length: 6234, dtype: object

# %% [markdown]
# ## Word Clouds

# %% [markdown]
# ### Word Clouds - Description

# %%
description = list(netfilx_raw_data['description'])
wordcloud = WordCloud(width=1600, height=800,max_font_size=180, max_words=150,background_color="white")\
.generate(" ".join(description))
plt.figure(figsize=(16,8))
plt.imshow(wordcloud,interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ### Word Clouds - Title

# %%
title = list(netfilx_raw_data['title'])
wordcloud = WordCloud(width=1600, height=800,max_font_size=180, max_words=150,background_color="white")\
.generate(" ".join(title))
plt.figure(figsize=(16,8))
plt.imshow(wordcloud,interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ### Word Clouds - Movie type

# %%
movie_type = list(netfilx_raw_data['listed_in'])
wordcloud = WordCloud(width=1600, height=800,max_font_size=180, max_words=150,background_color="white")\
.generate(" ".join(movie_type))
plt.figure(figsize=(16,8))
plt.imshow(wordcloud,interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ## Step 3: Recommendation System - Content based

# %% [markdown]
# ### Let's see if there is missing values on the dataset

# %%
netfilx_raw_data.isnull().sum()
# Out:
# show_id              0
# type                 0
# title                0
# director          1969
# cast               570
# country            476
# date_added          11
# release_year         0
# rating              10
# duration             0
# listed_in            0
# description          0
# Original_title       0
# dtype: int64

# %% [markdown]
# As we can see the columns 'directiors', 'cast', 'country', 'date_added' and 'rating' contain missing value. The easiest eway would be to remove all rows contains missing value. However, this will lead to the loss of a significant amount of data. Here, I decided to remove all columns that contain missing values (even if interresting information for the RS design will be remove, e.g. cast).
#
# The new dataset will only includes:
# - type
# - title
# - listed_in
# - description

# %%
netfilx_raw_data.drop(["show_id","director","cast","country","date_added","release_year","rating","duration"],\
                      axis=1,inplace=True)
netfilx_raw_data.head()
# Out:
#       type                           title                  listed_in  \
# 0    Movie  norm north king size adventure  child family movie comedy
# 1    Movie           jandino whatever take             standup comedy
# 2  TV Show               transformer prime                     kid tv
# 3  TV Show      transformer robot disguise                     kid tv
# 4    Movie                     realityhigh                     comedy
#
#                                          description  \
# 0  planning awesome wedding grandfather polar bea...
# 1  jandino asporaat riff challenge raise kid sere...
# 2  help three human ally autobots protect earth o...
# 3  prison ship crash unleashes hundred decepticon...
# 4  nerdy high schooler dani finally attracts inte...
#
#                             Original_title
# 0  Norm of the North: King Sized Adventure
# 1               Jandino: Whatever it Takes
# 2                       Transformers Prime
# 3         Transformers: Robots in Disguise
# 4                             #realityhigh

# %%
# Soup of word to feed the recommemndation model
netfilx_raw_data["WordSoup"] = netfilx_raw_data['title'] + '  ' + netfilx_raw_data['description'] + ' ' + netfilx_raw_data['listed_in'] 
netfilx_raw_data["WordSoup"]
netfilx_raw_data.drop(["type","title","listed_in","description"],axis=1,inplace=True)

#calculate the similarity matrix (cosine distance)
Vectorizer = TfidfVectorizer(norm = None)
tfidf_scores = Vectorizer.fit_transform(netfilx_raw_data['WordSoup'])
similiraty_cosine_matrix = cosine_similarity(tfidf_scores, tfidf_scores)

movie_titles = netfilx_raw_data['Original_title']
indices = pd.Series(netfilx_raw_data.index, index=netfilx_raw_data['Original_title'])

netfilx_raw_data.head()
# Out:
#                             Original_title  \
# 0  Norm of the North: King Sized Adventure
# 1               Jandino: Whatever it Takes
# 2                       Transformers Prime
# 3         Transformers: Robots in Disguise
# 4                             #realityhigh
#
#                                             WordSoup
# 0  norm north king size adventure  planning aweso...
# 1  jandino whatever take  jandino asporaat riff c...
# 2  transformer prime  help three human ally autob...
# 3  transformer robot disguise  prison ship crash ...
# 4  realityhigh  nerdy high schooler dani finally ...

# %% [markdown]
# ## Step 4: Recommendation System testing
# I tested the recommandation system on 4 movies: 'The Meaning of Monty Python', 'Men in Black', 'Naruto Shippuden : Blood Prison' and 'Hitch'

# %%
get_recommendations(netfilx_raw_data,'The Meaning of Monty Python',similiraty_cosine_matrix,indices,'Original_title')
# Out:
# You watched 'The Meaning of Monty Python', you may also like:
#
# Recommendation #1: Monty Python: The Meaning of Live
# Recommendation #2: Monty Python: Live at Aspen
# Recommendation #3: Monty Python's Personal Best
# Recommendation #4: Monty Python: Before the Flying Circus
# Recommendation #5: Monty Python's Almost the Truth
# Recommendation #6: Monty Python's Flying Circus
# Recommendation #7: Monty Python Best Bits (mostly)
# Recommendation #8: Monty Python and the Holy Grail
# Recommendation #9: Monty Python's Fliegender Zirkus
# Recommendation #10: Monty Python Live (Mostly): One Down, Five to Go

# %%
get_recommendations(netfilx_raw_data,'Men in Black',similiraty_cosine_matrix,indices,'Original_title')
# Out:
# You watched 'Men in Black', you may also like:
#
# Recommendation #1: Beyond Skyline
# Recommendation #2: Men in Black II
# Recommendation #3: Extinction
# Recommendation #4: Marvel's Agents of S.H.I.E.L.D.
# Recommendation #5: Bon Cop Bad Cop 2
# Recommendation #6: Bon Cop, Bad Cop
# Recommendation #7: District 9
# Recommendation #8: Wild Wild West
# Recommendation #9: Battle Drone
# Recommendation #10: The Truth Seekers

# %%
get_recommendations(netfilx_raw_data,'Naruto Shippuden : Blood Prison',similiraty_cosine_matrix,indices,'Original_title')
# Out:
# You watched 'Naruto Shippuden : Blood Prison', you may also like:
#
# Recommendation #1: Naruto Shippuden: The Movie
# Recommendation #2: Naruto
# Recommendation #3: Naruto Shippûden the Movie: Bonds
# Recommendation #4: Naruto Shippuden: The Movie: The Lost Tower
# Recommendation #5: Naruto the Movie 2: Legend of the Stone of Gelel
# Recommendation #6: Naruto the Movie: Ninja Clash in the Land of Snow
# Recommendation #7: Naruto Shippûden the Movie: The Will of Fire
# Recommendation #8: Naruto the Movie 3: Guardians of the Crescent Moon Kingdom
# Recommendation #9: Expo
# Recommendation #10: InuYasha the Movie: Affections Touching Across Time

# %%
get_recommendations(netfilx_raw_data,'Hitch',similiraty_cosine_matrix,indices,'Original_title')
# Out:
# You watched 'Hitch', you may also like:
#
# Recommendation #1: All's Well, End's Well (2009)
# Recommendation #2: #Roxy
# Recommendation #3: Blood Money
# Recommendation #4: Boy Bye
# Recommendation #5: Dating Around
# Recommendation #6: Furthest Witness
# Recommendation #7: Blind Date
# Recommendation #8: Tattah
# Recommendation #9: First Impression
# Recommendation #10: One Day

# %% [markdown]
# ## Conclusion
#
# The recommendations made by the CB-RS seems to be coherent. For ‘Naruto Shippuden’, the movies and series related to Naruto are listed. Regarding 'The Meaning of Monty Python', Monty Python-related movies are listed. For ‘Men in Black’ movie talking about aliens or cops are proposed. Finally, romance movies are suggested for ‘Hitch’.
#
# Better recommendations can be obtained with the cast, country and director in the CB-RS.
